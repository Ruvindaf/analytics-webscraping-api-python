# %%
import requests

#Using API Key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=600104.SHH&outputsize=full&apikey=XXXXXXXXXXXXXXXXXXX'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': '600104.SHH', '3. Last Refreshed': '2025-07-10', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-07-10': {'1. open': '17.2300', '2. high': '17.3900', '3. low': '16.9900', '4. close': '17.1100', '5. volume': '42793007'}, '2025-07-09': {'1. open': '17.4400', '2. high': '17.5900', '3. low': '17.2100', '4. close': '17.2300', '5. volume': '35121264'}, '2025-07-08': {'1. open': '17.2800', '2. high': '17.5400', '3. low': '17.1600', '4. close': '17.4700', '5. volume': '43385123'}, '2025-07-07': {'1. open': '17.0600', '2. high': '17.5000', '3. low': '16.9700', '4. close': '17.3400', '5. volume': '58921999'}, '2025-07-04': {'1. open': '16.3000', '2. high': '17.2000', '3. low': '16.2800', '4. close': '17.0600', '5. volume': '87181714'}, '2025-07-03': {'1. open': '16.0000', '2. high': '16.2900', '3. low': '16.0000', '4. close': '16.2800', '5. volume': '24
# ...

# %%
import pandas as pd

df_shang=pd.DataFrame(data)

# %%
df_shang
# Out:
#                                                            Meta Data  \
# 1. Information     Daily Prices (open, high, low, close) and Volumes
# 2. Symbol                                                 600104.SHH
# 3. Last Refreshed                                         2025-07-10
# 4. Output Size                                             Full size
# 5. Time Zone                                              US/Eastern
# ...                                                              ...
# 2004-07-13                                                       NaN
# 2004-07-12                                                       NaN
# 2004-07-09                                                       NaN
# 2004-07-08                                                       NaN
# 2004-07-07                                                       NaN
#
#                                                  Time Series (Daily)
# 1. Information                                                   NaN
# ...
